# %% [markdown]
# # Regression Analysis
# **Types of Recognition**
# - Linear Regression
# - Multi - Linear Regression
# - Lasso Regression
# - Ridge Regression
# - Polynomail Regression
# - Decision Tree Regression
# - Random Forest Regression
# - Support verctor machine
# - K-Nearest Neighbour Algorithum

# %%
import pandas as pd

# %%
dataset = pd.read_csv('E:\\cgpa.csv')
dataset.head()
# Out:
#    cgpa  package
# 0  2.75    13.07
# 1  3.90    19.73
# 2  3.46    17.59
# 3  3.20    15.29
# 4  2.31    13.42

# %%
dataset.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
x = dataset[['cgpa']
y = dataset['package']

# %%
# check graph
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(x='cgpa', y='package', data = dataset)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state=32)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr.predict([[3.90]])
# Out:
# E:\Anaconda Installed\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([19.41457461])

# %%
dataset.head()
# Out:
#    cgpa  package
# 0  2.75    13.07
# 1  3.90    19.73
# 2  3.46    17.59
# 3  3.20    15.29
# 4  2.31    13.42

# %%
lr.score(x_test,y_test)*100
# Out:
# 89.64263725365566

# %% [markdown]
# > Now lets test by finding the coefficients and intercept of the dataset

# %%
lr.coef_
# Out:
# array([4.862127])

# %%
lr.intercept_
# Out:
# np.float64(0.45227931444982694)

# %% [markdown]
# y = 4.862127x + 0.452279 <br>
# y = mx + c

# %%
# now lets check by putting the value of the x into it
4.862127 * 3.90 + 0.45227931444982694
# Out:
# 19.414574614449826

# %%
plt.figure(figsize = (5, 4))
sns.scatterplot(x='cgpa', y='package', data=dataset)
plt.plot(dataset['cgpa'], lr.predict(x), color='red')
plt.legend(['org', 'predict line'])
plt.savefig('predict.jpg')
plt.show()

# %%
sns.regplot(x='cgpa', y='package', data=dataset)
plt.show()

# %%
plt.plot(dataset['cgpa'], lr.predict(x))
plt.show()

# %% [markdown]
# # Multiple Linear Regression

# %%
dataset.head()
# Out:
#    cgpa  package
# 0  2.75    13.07
# 1  3.90    19.73
# 2  3.46    17.59
# 3  3.20    15.29
# 4  2.31    13.42

# %%
dataset2 = pd.read_csv(r"E:\experience.csv")

# %%
dataset2.head()
# Out:
#    age  experience    salary
# 0   58        37.0  78974.33
# 1   48        28.3  64824.99
# 2   34        16.3  46322.36
# 3   27         7.5  33135.04
# 4   40        17.3  45913.26

# %%
dataset2.shape
# Out:
# (200, 3)

# %%
dataset2.isnull().sum()
# Out:
# age           0
# experience    0
# salary        0
# dtype: int64

# %%
sns.regplot(x='age', y='experience', data=dataset2)
plt.show()

# %%
sns.pairplot(data=dataset2)
plt.show()

# %%
sns.heatmap(data=dataset2.corr(), annot=True)
# Out:
# <Axes: >

# %%
x = dataset2.iloc[:, :-1]

# %%
sns.pairplot(data=dataset)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
y = dataset2['salary']

# %%
x_train, x_test, y_train, t_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
lr = LinearRegression()
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
lr.predict([[32,23]])
# Out:
# E:\Anaconda Installed\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([53845.63686593])

# %%
lr.score(x_test, y_test)*100
# Out:
# -30819286809.12535

# %%
dataset2.head()
# Out:
#    age  experience    salary
# 0   58        37.0  78974.33
# 1   48        28.3  64824.99
# 2   34        16.3  46322.36
# 3   27         7.5  33135.04
# 4   40        17.3  45913.26

# %%
lr.predict([[34, 16.3]])
# Out:
# E:\Anaconda Installed\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([44257.351265])

# %%
lr.score(x_test, y_test)
# Out:
# -308192868.0912535

# %%
lr.coef_
# Out:
# array([  66.96173322, 1451.07598021])

# %%
lr.intercept_
# Out:
# np.float64(18328.11385799542)

# %%
66.96173322*34 + 1451.07598021*16.3 + 18328.11385799542
# Out:
# 44257.35126489842
